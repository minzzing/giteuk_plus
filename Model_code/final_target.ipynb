# %% [markdown]
# ## 라이브러리 import

# %%
import pandas as pd  #데이터 분석 라이브러리
import numpy as np # 계산 라이브러리

import matplotlib as mpl # 그래프 라이브러리
import matplotlib.pyplot as plt #pyplot 그래프 라이브러리
import matplotlib.font_manager as fm  #그래프 폰트 라이브러리
from pandas import Series, DataFrame

plt.rc("font", family="Malgun Gothic") #폰트 맑은 고딕 적용

# %% [markdown]
# ## 데이터 불러오기

# %%
kmeans = pd.read_csv('../Data/Result/kmeans.csv',encoding='cp949') #kmeans 타겟 클러스터 데이터
kmedoids = pd.read_csv('../Data/Result/k-medoids.csv',encoding='cp949') #kmedoids 타겟 클러스터 데이터
gmm = pd.read_csv('../Data/Result/gmm.csv',encoding='cp949') #gmm타겟 클러스터 데이터
df = pd.read_csv('../Data/Preprocessing/활성화지표_추가본.csv',encoding='cp949') #전체 데이터
re_city = pd.read_csv('../Data/Preprocessing/re_city.csv',encoding='cp949') #재생도시 데이터

# %%
kmeans
# Out:
#     과거대비인구변화(%)  최근인구변화(연속감소년수)  과거대비사업체변화(%)  최근사업체변화(연속감소년수)  노후건축물비율(%)  \
# 0    -71.395349               3     -2.691790                1   77.192982
# 1    -37.690513               3    -15.185185                4   54.545455
# 2    -57.091410               5     -0.800000                1   75.487013
# 3    -64.354556               3     -6.558862                5   87.413555
# 4    -58.991001               5    -11.170213                2   81.572052
# ..          ...             ...           ...              ...         ...
# 92   -50.225033               5    -13.950073                4   90.035273
# 93   -44.188005               4    -33.160622                4   82.733813
# 94   -50.376510               2    -10.462472                5   53.546911
# 95   -37.813261               4      0.442478                1   50.000000
# 96   -35.860909               3     -8.489526                3   73.132724
#
#       노인인구비율  기초생활 대상자 비율      행정동코드
# 0   4.398734     0.016852  1101054.0
# 1   6.083636     0.019178  1101057.0
# 2   4.875425     0.016791  1101060.0
# 3   5.176142     0.053336  1101063.0
# 4   5.805782     0.032399  1101064.0
# ..       ...          ...        ...
# 92  5.078967     0.036744  1124051.0
# 93  5.456130     0.047405  1124054.0
# 94  6.911884     0.019337  1124068.0
# 95  7.034671     0.007161  1125059.0
# 96  5.735823     0.034588  1125066.0
#
# [97 rows x 8 columns]

# %%
kmedoids
# Out:
#     과거대비인구변화(%)  최근인구변화(연속감소년수)  과거대비사업체변화(%)  최근사업체변화(연속감소년수)  노후건축물비율(%)  \
# 0    -71.395349               3     -2.691790                1   77.192982
# 1    -57.091410               5     -0.800000                1   75.487013
# 2    -64.354556               3     -6.558862                5   87.413555
# 3    -58.991001               5    -11.170213                2   81.572052
# 4    -60.099208               5     -9.995818                2   91.774383
# ..          ...             ...           ...              ...         ...
# 71   -39.658110               3    -24.008811                3   64.174455
# 72   -50.225033               5    -13.950073                4   90.035273
# 73   -44.188005               4    -33.160622                4   82.733813
# 74   -50.376510               2    -10.462472                5   53.546911
# 75   -28.072692               4     -4.522613                3   98.275862
#
#       노인인구비율  기초생활 대상자 비율      행정동코드
# 0   4.398734     0.016852  1101054.0
# 1   4.875425     0.016791  1101060.0
# 10  5.159952     0.103489  1107068.0
# 11  6.138646     0.095925  1108076.0
# 12  4.530440     0.069479  1108077.0
# 13  7.749169     0.035987  1108078.0
# 14  4.099747     0.107682  1109061.0
# 15  3.718912     0.154407  1109062.0
# 16  5.007851     0.071465  1109069.0
# 17  4.660000     0.113832  1110056.0
# 18  4.650777     0.114558  1111052.0
# 19  6.199504     0.104364  1111058.0
# 20  5.086880     0.089900  1111064.0
# 21  4.383035     0.095144  1111076.0
# 22  4.778128     0.137257  1111078.0
# 23  5.436329     0.058850  1112068.0
# 24  6.778701     0.032559  1114068.0
# 25  4.722273     0.179184  1116054.0
# 26  3.600454     0.220490  1116065.0
# 27  4.226384     0.147374  1116066.0
# 28  5.409194     0.058971  1118058.0
# 29  5.711804     0.044427  1119065.0
# 30  5.746367     0.061636  1119066.0
# 31  5.862678     0.042651  1119067.0
# 32  5.431365     0.038236  1120066.0
# 33  5.620063     0.032852  1120072.0
# 34  5.993350     0.017732  1122062.0
# 35  4.095778     0.025112  1123068.0
# 36  7.575863     0.033919  1123071.0
# 37  4.800990     0.107494  1123073.0
# 38  5.391161     0.073116  1123074.0
# 39  3.300945     0.221386  1123075.0
# 40  6.788057     0.008022  1123080.0
# 41  5.456130     0.047405  1124054.0

# %%
raw_data = df[['시도명','자치구','행정동명','과거대비인구변화(%)','최근인구변화(연속감소년수)','과거대비사업체변화(%)','최근사업체변화(연속감소년수)','노후건축물비율(%)', '노인인구비율', 
                  '기초생활 대상자 비율','행정동코드','재생도시']]

# %% [markdown]
# ## 세 클러스터에서 겹치는 데이터만 추출

# %%
#각 모델에서 행정동 코드만 추출
k_mean = kmeans['행정동코드'] 
k_medoids = kmedoids['행정동코드']
g_mm = gmm['행정동코드']

#set 하기 위해 값만 뽑아옴
km_val = k_mean.values
kd_val = k_medoids.values
g_val = g_mm.values

#set진행
km = set(km_val)
kd= set(kd_val)
g = set(g_val)

# %%
final = km&kd&g #set을 이용해 겹치는 데이터 추출

# %%
final_df = pd.DataFrame(final).rename(columns={0:'행정동코드'}) #결과물 dataframe형태로 바꾸기

# %%
final_df
# Out:
#         행정동코드
# 0   1123073.0
# 1   1112068.0
# 2   1101063.0
# 3   1123080.0
# 4   1111076.0
# 5   1106089.0
# 6   1120066.0
# 7   1109061.0
# 8   1103053.0
# 9   1124054.0
# 10  1119065.0
# 11  1119066.0
# 12  1119067.0
# 13  1102054.0
# 14  1102060.0
# 15  1108076.0
# 16  1108077.0
# 17  1107055.0
# 18  1108078.0
# 19  1123068.0
# 20  1101054.0

# %% [markdown]
# ## 행정동 코드를 이용해 타겟 데이터의 정보 추출

# %%
final_target = pd.merge(final_df,raw_data,on=['행정동코드'],how='left')
final_target_all = pd.merge(final_target,re_city,on=['행정동코드'],how='left')

# %%
final_target_all
# Out:
#         행정동코드    시도명         자치구     행정동명  과거대비인구변화(%)  최근인구변화(연속감소년수)  \
# 0   1123073.0  서울특별시   서울특별시 강남구     일원1동   -35.470532               5
# %%
final_final_target
# Out:
#         행정동코드    시도명         자치구     행정동명  과거대비인구변화(%)  최근인구변화(연속감소년수)  \
# 0   1123073.0  서울특별시   서울특별시 강남구     일원1동   -35.470532               5
# 1   1112068.0  서울특별시   서울특별시 은평구      수색동   -65.411820               4
# 2   1101063.0  서울특별시   서울특별시 종로구  종로5·6가동   -64.354556               3
# 3   1123080.0  서울특별시   서울특별시 강남구     개포2동   -39.658110               3
# 4   1111076.0  서울특별시   서울특별시 노원구   상계3·4동   -31.643887               4
# 5   1106089.0  서울특별시  서울특별시 동대문구     이문1동   -42.260503               5
# 7   1109061.0  서울특별시   서울특별시 강북구      번2동   -38.284953               5
# 8   1103053.0  서울특별시   서울특별시 용산구      남영동   -37.757063               5
# 9   1124054.0  서울특별시   서울특별시 송파구     거여2동   -44.188005               4
# 10  1119065.0  서울특별시  서울특별시 영등포구     신길3동   -40.898711               2
# 11  1119066.0  서울특별시  서울특별시 영등포구     신길4동   -54.382555               4
# 12  1119067.0  서울특별시  서울특별시 영등포구     신길5동   -61.490638               4
# 17  1107055.0  서울특별시   서울특별시 중랑구     면목5동   -38.042701               4
# 19  1123068.0  서울특별시   서울특별시 강남구     개포1동   -82.499049               5
#
#     과거대비사업체변화(%)  최근사업체변화(연속감소년수)  노후건축물비율(%)    노인인구비율  기초생활 대상자 비율  재생도시
# 0      -8.098988                2   87.234043  4.800990     0.107494   0.0
# 1     -41.530055                5   81.382979  5.436329     0.058850   0.0
# 2      -6.558862                5   87.413555  5.176142     0.053336   0.0
# 3     -24.008811                3   64.174455  6.788057     0.008022   0.0
# 4     -28.940986                4   89.918256  4.383035     0.095144   0.0
# 5     -20.799408                4   89.893617  6.585801     0.031246   0.0
# 7      -9.188034                2   86.681465  4.099747     0.107682   0.0
# 8      -7.171776                1   88.413098  5.094315     0.177594   0.0
# 9     -33.160622                4   82.733813  5.456130     0.047405   0.0
# 10    -25.583658                5   88.372093  5.711804     0.044427   0.0
# 11    -35.067437                4   89.122373  5.746367     0.061636   0.0
# 12    -23.760684                4   86.467662  5.862678     0.042651   0.0
# 17    -25.418060                4   77.196885  6.794037     0.051702   0.0
# 19    -64.542936                3   74.074074  4.095778     0.025112   0.0

# %%
final_final_target.to_csv('../Data/Result/final_target_cluster.csv',encoding='cp949',index=False)

# %% [markdown]
# ## 타겟 클러스터 행정동 특성 도출

# %%
target_infor = final_final_target[['과거대비인구변화(%)','최근인구변화(연속감소년수)','과거대비사업체변화(%)','최근사업체변화(연속감소년수)','노후건축물비율(%)',
                                       '노인인구비율','기초생활 대상자 비율']] #타겟 클러스터 행정동 특성 변수 뽑기

# %%
target_infor
# Out:
#     과거대비인구변화(%)  최근인구변화(연속감소년수)  과거대비사업체변화(%)  최근사업체변화(연속감소년수)  노후건축물비율(%)  \
# 0    -35.470532               5     -8.098988                2   87.234043
# 1    -65.411820               4    -41.530055                5   81.382979
# 2    -64.354556               3     -6.558862                5   87.413555
# 3    -39.658110               3    -24.008811                3   64.174455
# 4    -31.643887               4    -28.940986                4   89.918256
# 5    -42.260503               5    -20.799408                4   89.893617
# 7    -38.284953               5     -9.188034                2   86.681465
# 8    -37.757063               5     -7.171776                1   88.413098
# 9    -44.188005               4    -33.160622                4   82.733813
# 10   -40.898711               2    -25.583658                5   88.372093
# 11   -54.382555               4    -35.067437                4   89.122373
# 12   -61.490638               4    -23.760684                4   86.467662
# 17   -38.042701               4    -25.418060                4   77.196885
# 19   -82.499049               5    -64.542936                3   74.074074
#
#       노인인구비율  기초생활 대상자 비율
# 0   4.800990     0.107494
# 1   5.436329     0.058850
# 2   5.176142     0.053336
# 3   6.788057     0.008022
# 4   4.383035     0.095144
# 5   6.585801     0.031246
# 7   4.099747     0.107682
# 8   5.094315     0.177594
# 9   5.456130     0.047405
# 10  5.711804     0.044427
# 11  5.746367     0.061636
# 12  5.862678     0.042651
# 17  6.794037     0.051702
# 19  4.095778     0.025112

# %%
target_infor.iloc[:,1].count()
# Out:
# 14

# %%
#각 변수별 평균
aad = []
for i in range(0,7):
        a  = target_infor.iloc[:,i].sum()/14
        aad.append(a)

# %%
aad
# Out:
# [-48.310220280936626,
#  4.071428571428571,
#  -25.273593948893513,
#  3.5714285714285716,
#  83.79131197382522,
#  5.430800702071428,
#  0.06516429479052267]

# %% [markdown]
# ## 전체 집단 특성 도출(타겟 클러스터의 특성과 비교하기 위함)

# %%
total = raw_data[['과거대비인구변화(%)','최근인구변화(연속감소년수)','과거대비사업체변화(%)','최근사업체변화(연속감소년수)','노후건축물비율(%)','노인인구비율','기초생활 대상자 비율']]

# %%
total
# Out:
#      과거대비인구변화(%)  최근인구변화(연속감소년수)  과거대비사업체변화(%)  최근사업체변화(연속감소년수)  노후건축물비율(%)  \
# 0     -13.703589               2      0.338696                1   73.636364
# 1     -71.395349               3     -2.691790                1   77.192982
# 2     -28.333333               5      4.251386                1   75.547703
# 3      -4.272303               4      2.092050                0   71.133568
# 4     -37.690513               3    -15.185185                4   54.545455
# ..           ...             ...           ...              ...         ...
# 418   -14.897188               5     -0.754549                1   53.799392
# 419   -14.202147               3     -5.244253                3   63.047138
# 420   -16.278442               3     -3.260870                2   62.685851
# 421    -6.641188               3     -8.824392                1   74.177313
# 422   -10.596548               4     -2.389974                1   63.755679
#
#        노인인구비율  기초생활 대상자 비율
# 0    5.471891     0.014819
# 1    4.398734     0.016852
# 2    5.606197     0.015518
# 3    5.428951     0.007883
# 4    6.083636     0.019178
# ..        ...          ...
# 418  6.271762     0.028701
# 419  6.160245     0.019830
# 420  5.881427     0.054802
# 421  5.778005     0.056432
# 422  5.979868     0.032574
#
# [423 rows x 7 columns]

# %%
total.iloc[:,1].count()
# Out:
# 423

# %%
#각 변수별 평균
aad_total = []
for i in range(0,7):
        b  = total.iloc[:,i].sum()/423
        aad_total.append(b)

# %%
aad_total
# Out:
# [-19.482527157523638,
#  3.5768321513002364,
#  -5.058446701741968,
#  1.962174940898345,
#  70.9393032992157,
#  6.349491076356974,
#  0.03851633197109219]
